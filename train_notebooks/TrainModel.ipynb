# %%
ROOT_DIR = '/content/drive/MyDrive/MPIT_2025_CNN_MONITORING/data'

# %%
# %%capture
# !pip install ultralytics

# %%
import os
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/MPIT_2025_CNN_MONITORING/yolov8s.pt")
results = model.train(
    data=os.path.join(ROOT_DIR, "config.yaml"),
    epochs=5,
    project='/content/drive/MyDrive/MPIT_2025_CNN_MONITORING/runs'
)
# Out:
# Ultralytics 8.3.229 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
